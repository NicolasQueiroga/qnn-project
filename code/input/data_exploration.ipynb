# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.io as sio
import cv2

# %%
TRAIN_PATH = 'UCF-QNRF_ECCV18/Train'
TEST_PATH = 'UCF-QNRF_ECCV18/Test'

# %%
# read 10 images from the training set (its composed by a jpg and a mat file)
# example: img_0001.jpg and img_0001_ann.mat

for i in range(1, 3):
    img = cv2.imread(f'{TRAIN_PATH}/img_{i:04d}.jpg')
    mat = sio.loadmat(f'{TRAIN_PATH}/img_{i:04d}_ann.mat')
    points = mat['annPoints']
    plt.figure(figsize=(10, 10))
    plt.imshow(img)
    plt.scatter(points[:, 0], points[:, 1], s=1, c='r')
plt.show()
